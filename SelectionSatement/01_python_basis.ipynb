# %%
a=5

# %%
a
# Out:
# 5

# %%
b=32

# %%
a+b
# Out:
# 37

# %%
name ='Harry'

# %%
print('Hello,world')
# Out:
# Hello,world

# %%
"""
this is for t
o make the mu
ltiple lines of comment"""
# Out:
# '\nthis is for t\no make the mu\nltiple lines of comment'

# %%
print(type(a))
# Out:
# <class 'int'>

# %%
print(type(name))
# Out:
# <class 'str'>

# %% [markdown]
# ## TypeCasting

# %%
a='4456'
b='5677'

# %%
print(a+b)
# Out:
# 44565677

# %%
int(a)+int(b) #typecasting
# Out:
# 10133

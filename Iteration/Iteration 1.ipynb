# %%
a=["Deepak","Kumar",'Deshwal']

for i in a:
    print(i)
# Out:
# Deepak
# Kumar
# Deshwal

# %%
for i in a:
    for b in i:
        print(b)
# Out:
# D
# e
# e
# p
# a
# k
# K
# u
# m
# a
# r
# D
# e
# s
# h
# w
# a
# l

# %%
for i in ra

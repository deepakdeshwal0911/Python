# %%
a=int(input('Enter the value of the a:\n'))
# Out:
# Enter the value of the a:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 a=int(input('Enter the value of the a:\n'))
#
# ValueError: invalid literal for int() with base 10: ''

# %%
a=int(input('Enter the value of the a:\n'))
if(a>53):
    print('Greater')
else:
    print('Smaller')
# Out:
# Enter the value of the a:
#  56
# Greater

# %%
a=int(input('Enter the value of the a:\n'))
if a<5:
    print('Smaller')
else:
    print('Greater')
# Out:
# Enter the value of the a:
#  45
# Greater

# %% [markdown]
# ### Defining Funcation

# %%
def avg(a,b):
    print((a+b)/2)

# %%
avg(2,3)
# Out:
# 2.5

# %%
a=int(input("Enter the Angle A"))
b= int(input("Enter the angle B"))
c=int(input("Enter the angle of C"))
a!=0
b!=0
c!=0

T=a+b+c
if(T==180):
    print("Yes,it is triangle ")
else:
    print("No, it is not the triangle")
# Out:
# Enter the Angle A 60
# Enter the angle B 60
# Enter the angle of C 60
# Yes,it is triangle
